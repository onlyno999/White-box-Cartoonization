# %% [markdown]
# #1. 下载白盒卡通化库

# %%
# !pwd
# !ls
# %cd /content
# !git clone https://github.com/SystemErrorWang/White-box-Cartoonization.git
# Out:
# /content
# sample_data
# /content
# Cloning into 'White-box-Cartoonization'...
# remote: Enumerating objects: 199, done.
# remote: Total 199 (delta 0), reused 0 (delta 0), pack-reused 199
# Receiving objects: 100% (199/199), 44.60 MiB | 12.62 MiB/s, done.
# Resolving deltas: 100% (74/74), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #2. 安装环境依赖包

# %%
# !pip uninstall tensorflow -y
# !pip install opencv-python tqdm numpy==1.16.1 tensorflow-gpu==1.15.0 
# 如果执行出现红字：You must restart the runtime in order to use newly installed versions. 那么，这个时候
# 就要点击它下面的 RESART TUNTIME 按钮， 再点击三角形运行一次这部分代码就可以了。等它再运行完毕就没问题了。
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
# Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 17.3 MB 14.1 MB/s
# ...
#      |████████████████████████████████| 411.5 MB 7.8 kB/s
# ...
#      |████████████████████████████████| 3.8 MB 65.4 MB/s
# ...
#      |████████████████████████████████| 503 kB 56.1 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.2 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=64a0ebbe650d4006fe2f57f3bdec509d8f9b0e9fd1031291c3521b32be94db84
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
# ...

# %% [markdown]
# #3. 推理过程

# %%
# %cp drive/MyDrive/olnyno999/cvt2anime_video.py White-box-Cartoonization/test_code/
# %cd White-box-Cartoonization/test_code/
# Out:
# /content/White-box-Cartoonization/test_code

# %% [markdown]
# #4. 开始转视频

# %%
# !python cvt2anime_video.py --video '/content/x.mp4'  # xxxxx.mp4这里要改为你要转换的视频名称，且视频要放在sample_data同级目录下
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From cvt2anime_video.py:32: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/White-box-Cartoonization/test_code/network.py:23: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...
